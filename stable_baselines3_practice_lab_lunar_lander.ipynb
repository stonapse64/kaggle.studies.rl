# %% [markdown]
# # Stable-Baselines3 practice lab Lunar Lander
#
# Code snippets are
# - from the official documentation of [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) and
# - from [Reinforcement Learning in Python with Stable Baselines 3](https://pythonprogramming.net/introduction-reinforcement-learning-stable-baselines-3-tutorial/).

# %%
# imports

import gymnasium as gym
from stable_baselines3 import A2C, PPO
from stable_baselines3.common.evaluation import evaluate_policy
import tqdm
import os
# Out:
# 2025-01-05 19:14:50.769772: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736100890.783596    4365 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1736100890.787783    4365 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-05 19:14:50.802001: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# prepare output folders of model snapshots and logs for tensorboard
models_dir, logs_dir = "models/lunarlander/PPO", "logs/lunarlander"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(logs_dir):
    os.makedirs(logs_dir)

# %%
# create the cart pole environment
env = gym.make("LunarLander-v3", render_mode="rgb_array")
env.reset()
# Out:
# (array([ 1.15966795e-04,  1.41220427e+00,  1.17322486e-02,  5.70709035e-02,
#         -1.27612017e-04, -2.65754969e-03,  0.00000000e+00,  0.00000000e+00],
#        dtype=float32),
#  {})

# %%
# create the model of choice
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=logs_dir)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/stonapse/Projects/kaggle.studies.rl/.venv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
# train the model and save the snapshots and create the logs along the way
TIMESTEPS = 1e4 # timesteps for each training episode
episodes = 50 # number of training episodes
for episode in range(episodes):
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name="PPO")
    model.save(f"{models_dir}/{TIMESTEPS*(episode + 1)}")
# Out:
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -179     |
# | time/              |          |
# |    fps             | 780      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.7        |
# |    ep_rew_mean          | -188        |
# | time/                   |             |
# |    fps                  | 377         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007320149 |
# |    clip_fraction        | 0.0382      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00795     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 552         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00816    |
# |    value_loss           | 1.42e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.9        |
# |    ep_rew_mean          | -175        |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008565735 |
# |    clip_fraction        | 0.0146      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.0377     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 1.87e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.2        |
# |    ep_rew_mean          | -164        |
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 4           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010095766 |
# |    clip_fraction        | 0.0705      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.000784    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 228         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 792         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96           |
# |    ep_rew_mean          | -162         |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 5            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0051058037 |
# |    clip_fraction        | 0.0712       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00587     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 282          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00758     |
# |    value_loss           | 602          |
# ------------------------------------------
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.2     |
# |    ep_rew_mean     | -151     |
# | time/              |          |
# |    fps             | 823      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 12288    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | -150         |
# | time/                   |              |
# |    fps                  | 390          |
# |    iterations           | 2            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0115220975 |
# |    clip_fraction        | 0.091        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -6.13e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 289          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00679     |
# |    value_loss           | 620          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | -160        |
# | time/                   |             |
# |    fps                  | 344         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009737035 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.000107    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 293         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0045     |
# |    value_loss           | 742         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 113          |
# |    ep_rew_mean          | -159         |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 4            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0037752488 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | -9.89e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 392          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00237     |
# |    value_loss           | 781          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 122          |
# |    ep_rew_mean          | -163         |
# | time/                   |              |
# |    fps                  | 304          |
# |    iterations           | 5            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0056333616 |
# |    clip_fraction        | 0.0936       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | -0.000265    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 191          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00668     |
# |    value_loss           | 338          |
# ------------------------------------------
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 128      |
# |    ep_rew_mean     | -162     |
# | time/              |          |
# |    fps             | 842      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 22528    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 136         |
# |    ep_rew_mean          | -162        |
# | time/                   |             |
# |    fps                  | 435         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009943128 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | -0.0541     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 268         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00594    |
# |    value_loss           | 441         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | -157        |
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.006578887 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | -0.000562   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 129         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 398         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 149          |
# |    ep_rew_mean          | -149         |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 4            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0055625886 |
# |    clip_fraction        | 0.078        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | -0.000514    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 279          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0066      |
# |    value_loss           | 414          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 152         |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 311         |
# |    iterations           | 5           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007907505 |
# |    clip_fraction        | 0.0507      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -8.94e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 155         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00637    |
# |    value_loss           | 363         |
# -----------------------------------------
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 157      |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    fps             | 753      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 32768    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 170         |
# |    ep_rew_mean          | -119        |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010212585 |
# |    clip_fraction        | 0.0611      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.00065     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 113         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00993    |
# |    value_loss           | 303         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | -112        |
# | time/                   |             |
# |    fps                  | 316         |
# |    iterations           | 3           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007387606 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.0573      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.2        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00657    |
# |    value_loss           | 129         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 189         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 4           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011396941 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.016       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 136         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00453    |
# |    value_loss           | 192         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 201          |
# |    ep_rew_mean          | -106         |
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 5            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0063980045 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.158        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 119          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00467     |
# |    value_loss           | 258          |
# ------------------------------------------
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 213      |
# |    ep_rew_mean     | -106     |
# | time/              |          |
# |    fps             | 673      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 43008    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 224          |
# |    ep_rew_mean          | -99.1        |
# | time/                   |              |
# |    fps                  | 362          |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0039110724 |
# |    clip_fraction        | 0.00532      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.11         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 111          |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 268          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -91.7       |
# | time/                   |             |
# |    fps                  | 311         |
# |    iterations           | 3           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.013758881 |
# |    clip_fraction        | 0.0933      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72          |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00951    |
# |    value_loss           | 120         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 246         |
# |    ep_rew_mean          | -83         |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 4           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005928692 |
# |    clip_fraction        | 0.0269      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.411       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.1        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00834    |
# |    value_loss           | 112         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 261          |
# |    ep_rew_mean          | -76.8        |
# | time/                   |              |
# |    fps                  | 274          |
# |    iterations           | 5            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0057784053 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.99        |
# |    explained_variance   | 0.198        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.7         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00634     |
# |    value_loss           | 167          |
# ------------------------------------------
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 271      |
# |    ep_rew_mean     | -78.5    |
# | time/              |          |
# |    fps             | 653      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 53248    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 287          |
# |    ep_rew_mean          | -73.3        |
# | time/                   |              |
# |    fps                  | 370          |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0045853034 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.359        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.7         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00565     |
# |    value_loss           | 178          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 303         |
# |    ep_rew_mean          | -68.4       |
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 3           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.014482029 |
# |    clip_fraction        | 0.0745      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | 0.491       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.5        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 116         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 320         |
# |    ep_rew_mean          | -63         |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 4           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008064119 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.657       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.3        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00745    |
# |    value_loss           | 45.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 340         |
# |    ep_rew_mean          | -60.6       |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 5           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011292779 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10          |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 23.6        |
# -----------------------------------------
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 355      |
# |    ep_rew_mean     | -59      |
# | time/              |          |
# |    fps             | 660      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 63488    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 371         |
# |    ep_rew_mean          | -52.2       |
# | time/                   |             |
# |    fps                  | 357         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009127843 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.505       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.8        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00822    |
# |    value_loss           | 84.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 388          |
# |    ep_rew_mean          | -49.1        |
# | time/                   |              |
# |    fps                  | 291          |
# |    iterations           | 3            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0125869755 |
# |    clip_fraction        | 0.0979       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.551        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 89.1         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00701     |
# |    value_loss           | 136          |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -45.7     |
# | time/                   |           |
# |    fps                  | 276       |
# |    iterations           | 4         |
# |    time_elapsed         | 29        |
# |    total_timesteps      | 69632     |
# | train/                  |           |
# |    approx_kl            | 0.0150419 |
# |    clip_fraction        | 0.107     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.01     |
# |    explained_variance   | 0.632     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 192       |
# |    n_updates            | 330       |
# |    policy_gradient_loss | -0.00376  |
# |    value_loss           | 120       |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 417          |
# |    ep_rew_mean          | -41.1        |
# | time/                   |              |
# |    fps                  | 269          |
# |    iterations           | 5            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0039087078 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.937       |
# |    explained_variance   | 0.559        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.6         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00513     |
# |    value_loss           | 82.9         |
# ------------------------------------------
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 434      |
# |    ep_rew_mean     | -38      |
# | time/              |          |
# |    fps             | 426      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 73728    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 451          |
# |    ep_rew_mean          | -35          |
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 2            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0031384071 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.874       |
# |    explained_variance   | 0.851        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.06         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00416     |
# |    value_loss           | 17.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 474          |
# |    ep_rew_mean          | -30.7        |
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 3            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0058852867 |
# |    clip_fraction        | 0.069        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.744        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.57         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00594     |
# |    value_loss           | 23.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 490         |
# |    ep_rew_mean          | -27.6       |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 4           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011309845 |
# |    clip_fraction        | 0.0907      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.931      |
# |    explained_variance   | 0.271       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 77          |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00355    |
# |    value_loss           | 96.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -25.7        |
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 5            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0105876755 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.837        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.2          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00472     |
# |    value_loss           | 13.9         |
# ------------------------------------------
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 520      |
# |    ep_rew_mean     | -23.5    |
# | time/              |          |
# |    fps             | 617      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 83968    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 537        |
# |    ep_rew_mean          | -18        |
# | time/                   |            |
# |    fps                  | 333        |
# |    iterations           | 2          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.00937668 |
# |    clip_fraction        | 0.0453     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.02      |
# |    explained_variance   | 0.637      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 77.3       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00363   |
# |    value_loss           | 66.9       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 554        |
# |    ep_rew_mean          | -12.9      |
# | time/                   |            |
# |    fps                  | 280        |
# |    iterations           | 3          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.00917315 |
# |    clip_fraction        | 0.0677     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.492      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.9       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.00303   |
# |    value_loss           | 107        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 559         |
# |    ep_rew_mean          | -9.85       |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 4           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009322932 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00369    |
# |    value_loss           | 7.63        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 574          |
# |    ep_rew_mean          | -6.47        |
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 5            |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0036119139 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.57         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.4         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00276     |
# |    value_loss           | 109          |
# ------------------------------------------
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 585      |
# |    ep_rew_mean     | -3.06    |
# | time/              |          |
# |    fps             | 475      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 94208    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 603          |
# |    ep_rew_mean          | 4.91         |
# | time/                   |              |
# |    fps                  | 303          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0061697196 |
# |    clip_fraction        | 0.0664       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.813        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.8         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00489     |
# |    value_loss           | 44.2         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 618        |
# |    ep_rew_mean          | 10.2       |
# | time/                   |            |
# |    fps                  | 282        |
# |    iterations           | 3          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.00837443 |
# |    clip_fraction        | 0.0736     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.804     |
# |    explained_variance   | 0.644      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 88         |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0038    |
# |    value_loss           | 93.9       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 634          |
# |    ep_rew_mean          | 13.4         |
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 4            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0033585606 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.796       |
# |    explained_variance   | 0.648        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.8         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 133          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 649         |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 5           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.018958293 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.941      |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.66        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00372    |
# |    value_loss           | 23.7        |
# -----------------------------------------
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 655      |
# |    ep_rew_mean     | 22       |
# | time/              |          |
# |    fps             | 546      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 104448   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 665          |
# |    ep_rew_mean          | 26           |
# | time/                   |              |
# |    fps                  | 321          |
# |    iterations           | 2            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0068309368 |
# |    clip_fraction        | 0.0407       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.416        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.42         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00309     |
# |    value_loss           | 107          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 677          |
# |    ep_rew_mean          | 33.2         |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 3            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0055199675 |
# |    clip_fraction        | 0.0517       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.95        |
# |    explained_variance   | 0.51         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.93         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 57.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 674          |
# |    ep_rew_mean          | 35.6         |
# | time/                   |              |
# |    fps                  | 269          |
# |    iterations           | 4            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0067990273 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.804       |
# |    explained_variance   | 0.632        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.1         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00381     |
# |    value_loss           | 105          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 692         |
# |    ep_rew_mean          | 40.9        |
# | time/                   |             |
# |    fps                  | 263         |
# |    iterations           | 5           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.010984822 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.879      |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.2        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00341    |
# |    value_loss           | 122         |
# -----------------------------------------
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 704      |
# |    ep_rew_mean     | 43.8     |
# | time/              |          |
# |    fps             | 436      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 114688   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 716         |
# |    ep_rew_mean          | 44.8        |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.009864549 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.892      |
# |    explained_variance   | 0.718       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.7        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00373    |
# |    value_loss           | 52          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | 45.6        |
# | time/                   |             |
# |    fps                  | 268         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.007970361 |
# |    clip_fraction        | 0.0433      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.991      |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.8        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00389    |
# |    value_loss           | 71.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 738         |
# |    ep_rew_mean          | 48.5        |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 4           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.012094449 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.857      |
# |    explained_variance   | 0.716       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.42        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00559    |
# |    value_loss           | 46.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 744          |
# |    ep_rew_mean          | 51.5         |
# | time/                   |              |
# |    fps                  | 254          |
# |    iterations           | 5            |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0039472696 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.787       |
# |    explained_variance   | 0.707        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.61         |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 82.6         |
# ------------------------------------------
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 754      |
# |    ep_rew_mean     | 52.6     |
# | time/              |          |
# |    fps             | 435      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 124928   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 762         |
# |    ep_rew_mean          | 53.4        |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.011137671 |
# ...
# |    loss                 | 25          |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.00329    |
# |    value_loss           | 178         |
# -----------------------------------------
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 405      |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    fps             | 616      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 473088   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 416          |
# |    ep_rew_mean          | 110          |
# | time/                   |              |
# |    fps                  | 349          |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0038653112 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.683       |
# |    explained_variance   | 0.738        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.7         |
# |    n_updates            | 2310         |
# |    policy_gradient_loss | -0.00191     |
# |    value_loss           | 125          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 418         |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 3           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.003844466 |
# |    clip_fraction        | 0.0242      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.593      |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.2        |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | -0.000757   |
# |    value_loss           | 129         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 416         |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 4           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.006228424 |
# |    clip_fraction        | 0.0954      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.674      |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.4        |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.00491    |
# |    value_loss           | 80.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 405        |
# |    ep_rew_mean          | 107        |
# | time/                   |            |
# |    fps                  | 291        |
# |    iterations           | 5          |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 481280     |
# | train/                  |            |
# |    approx_kl            | 0.00786379 |
# |    clip_fraction        | 0.0979     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.661     |
# |    explained_variance   | 0.81       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 33.8       |
# |    n_updates            | 2340       |
# |    policy_gradient_loss | -0.00352   |
# |    value_loss           | 181        |
# ----------------------------------------
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 405      |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    fps             | 674      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 483328   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 407          |
# |    ep_rew_mean          | 103          |
# | time/                   |              |
# |    fps                  | 346          |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 485376       |
# | train/                  |              |
# |    approx_kl            | 0.0037072003 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.579       |
# |    explained_variance   | 0.74         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.1         |
# |    n_updates            | 2360         |
# |    policy_gradient_loss | -0.00221     |
# |    value_loss           | 171          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 405         |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 308         |
# |    iterations           | 3           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.007306341 |
# |    clip_fraction        | 0.0428      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.624      |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 83.3        |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | -0.00194    |
# |    value_loss           | 109         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 409         |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 4           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.004216399 |
# |    clip_fraction        | 0.0419      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.6        |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.9        |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | -0.000332   |
# |    value_loss           | 97.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 416          |
# |    ep_rew_mean          | 110          |
# | time/                   |              |
# |    fps                  | 282          |
# |    iterations           | 5            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0038275633 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.531       |
# |    explained_variance   | 0.774        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 99.8         |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | -0.0022      |
# |    value_loss           | 155          |
# ------------------------------------------
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 419      |
# |    ep_rew_mean     | 117      |
# | time/              |          |
# |    fps             | 685      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 493568   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 422          |
# |    ep_rew_mean          | 121          |
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 2            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 495616       |
# | train/                  |              |
# |    approx_kl            | 0.0033099381 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.462       |
# |    explained_variance   | 0.764        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 109          |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | -0.00203     |
# |    value_loss           | 92.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 415          |
# |    ep_rew_mean          | 123          |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 497664       |
# | train/                  |              |
# |    approx_kl            | 0.0051769866 |
# |    clip_fraction        | 0.0611       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.557       |
# |    explained_variance   | 0.789        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.2         |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -0.00276     |
# |    value_loss           | 125          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 416          |
# |    ep_rew_mean          | 128          |
# | time/                   |              |
# |    fps                  | 304          |
# |    iterations           | 4            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0052722036 |
# |    clip_fraction        | 0.0437       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.614       |
# |    explained_variance   | 0.845        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.9         |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | -0.00255     |
# |    value_loss           | 113          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 409          |
# |    ep_rew_mean          | 125          |
# | time/                   |              |
# |    fps                  | 290          |
# |    iterations           | 5            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 501760       |
# | train/                  |              |
# |    approx_kl            | 0.0043127546 |
# |    clip_fraction        | 0.0532       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.573       |
# |    explained_variance   | 0.804        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.17         |
# |    n_updates            | 2440         |
# |    policy_gradient_loss | -0.00206     |
# |    value_loss           | 91.9         |
# ------------------------------------------
# Logging to logs/lunarlander/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | 127      |
# | time/              |          |
# |    fps             | 732      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 503808   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 390         |
# |    ep_rew_mean          | 141         |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 505856      |
# | train/                  |             |
# |    approx_kl            | 0.006139188 |
# |    clip_fraction        | 0.0673      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.605      |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 103         |
# |    n_updates            | 2460        |
# |    policy_gradient_loss | -0.00299    |
# |    value_loss           | 127         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 389          |
# |    ep_rew_mean          | 141          |
# | time/                   |              |
# |    fps                  | 309          |
# |    iterations           | 3            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 507904       |
# | train/                  |              |
# |    approx_kl            | 0.0052309358 |
# |    clip_fraction        | 0.0751       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.598       |
# |    explained_variance   | 0.877        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.77         |
# |    n_updates            | 2470         |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 58.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 377         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 4           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 509952      |
# | train/                  |             |
# |    approx_kl            | 0.003907779 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.494      |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62.3        |
# |    n_updates            | 2480        |
# |    policy_gradient_loss | -0.00231    |
# |    value_loss           | 133         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 361         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 5           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 512000      |
# | train/                  |             |
# |    approx_kl            | 0.005230557 |
# |    clip_fraction        | 0.0364      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.561      |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39          |
# |    n_updates            | 2490        |
# |    policy_gradient_loss | -0.00135    |
# |    value_loss           | 138         |
# -----------------------------------------

# %% [markdown]
# Now, while the model trains, we can view the results over time <br>
# by opening a new terminal and doing: `tensorboard --logdir=logs/lunarlander`
#
# To see to which extend the GPU is used, type `nvidia-smi` into a new terminal.

# %%
# load and evaluate a formerly saved snapshot
model = PPO.load(f"{models_dir}/200000.0", env=env)
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
print(f"The mean reward is {mean_reward} with a standard deviation of {std_reward}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# The mean reward is 147.9203316 with a standard deviation of 95.44333679253258

# %%
# recreate env and load a formerly saved snapshot and render animations from it
env = gym.make("LunarLander-v3", render_mode="rgb_array")
env.reset()

model = PPO.load(f"{models_dir}/200000.0", env=env)

vec_env = model.get_env()
obs = vec_env.reset()

episodes = 2
total_reward_episode = 0

for episode in range(episodes):
    # VecEnv resets automatically but one could optionally reset it here
    # obs = vec_env.reset()
    done = False    
    total_reward_episode = 0
    while not done:
        action, _state = model.predict(obs, deterministic=True)
        obs, reward, done, info = vec_env.step(action)
        vec_env.render("human")
        total_reward_episode += reward

    print(f"Total reward in episode {episode + 1} was {total_reward_episode}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/stonapse/Projects/kaggle.studies.rl/.venv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# Total reward in episode 1 was [181.28253]
# Total reward in episode 2 was [-95.54287]

# %% [markdown]
# The Tensorboard comparison of the mean reward of the two models shows that
# - PPO maxes out 25k steps earlier
# - PPO reaches max-out on a steadier path
# - PPO holds the max-out whereas A2C shows a drop to ~470 after ~170k steps
# - PPO performs the 200k steps ~50% quicker
#
# ![Tensorboard](images/Tensorboard_rewart_mean_A2C_vs_PPO.png)
